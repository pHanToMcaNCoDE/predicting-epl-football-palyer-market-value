# %%
# %pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 11.1 MB/s  0:00:00m0:00:01
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install lightgbm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [lightgbm]
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from transfermarkt_utils import run_random_forest
from transfermarkt_utils import run_linear_regression
from transfermarkt_utils import run_light_gbm
from transfermarkt_utils import run_xgboost

# %%
final_model_data = pd.read_csv(
    "/Users/kachi/Documents/Thesis/data/processed/final_model_data_with_log.csv"
)

final_model_data.shape
# Out:
# (2116, 73)

# %%
final_model_data.head()
# Out:
#                league  season     club             player_name nation  \
# 0  ENG-Premier League  2122.0  Arsenal          aaron ramsdale    ENG
# 1  ENG-Premier League  2122.0  Arsenal  ainsley maitland niles    ENG
# 2  ENG-Premier League  2122.0  Arsenal    albert sambi lokonga    BEL
# 3  ENG-Premier League  2122.0  Arsenal     alexandre lacazette    FRA
# 4  ENG-Premier League  2122.0  Arsenal               ben white    ENG
#
#   position_fbref  age_fbref    born  matches_played  starts  ...  \
# 0             GK       23.0  1998.0              34      34  ...
# 1             MF       23.0  1997.0               8       2  ...
# 2             MF       21.0  1999.0              19      12  ...
# 3          FW,MF       30.0  1991.0              30      20  ...
# 4             DF       23.0  1997.0              32      32  ...
#
#    penalties_faced  penalties_saved  penalties_missed  penalties_conceded  \
# 0              6.0              5.0               0.0                 1.0
# ...

# %%
final_model_data[
    ["market_value_eur", "log_market_value"]
].head()
# Out:
#    market_value_eur  log_market_value
# 0        28000000.0         17.147715
# 1        10000000.0         16.118096
# 2        14000000.0         16.454568
# 3        15000000.0         16.523561
# 4        40000000.0         17.504390

# %%
final_model_data["log_market_value"].isna().sum()
# Out:
# np.int64(0)

# %%
final_model_data.columns.tolist()
# Out:
# ['league',
#  'season',
#  'club',
#  'player_name',
#  'nation',
#  'position_fbref',
#  'age_fbref',
#  'born',
#  'matches_played',
#  'starts',
#  'minutes',
#  'nineties',
#  'goals',
#  'assists',
#  'goal_contributions',
#  'non_penalty_goals',
#  'penalty_goals',
#  'penalty_attempts',
#  'yellow_cards',
#  'red_cards',
#  'goals_per90',
#  'assists_per90',
#  'ga_per90',
#  'npg_per90',
#  'npga_per90',
#  'shots',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'shots_per90',
#  'shots_on_target_per90',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'minutes_per_match',
#  'minutes_pct',
#  'starts_per_match',
#  'complete_matches',
#  'substitute_appearances',
#  'minutes_per_sub',
#  'unused_substitute',
#  'points_per_match',
#  'team_goals',
#  'team_goals_against',
#  'goal_difference',
#  'goal_difference_per90',
#  'on_off',
#  'second_yellows',
#  'fouls_committed',
#  'fouls_drawn',
#  'offsides',
#  'crosses',
#  'interceptions',
#  'tackles_won',
# ...

# %% [markdown]
# ## Modelling

# %%
# These features will not be used as predictors in the model. 
# They are deemed unnecessary with log_market_value/market_value_eur as the target variable.

identifier_columns = [
    "league",
    "club",
    "player_name",
    "nation",
    "position_fbref",
    "position_tm",
    "market_value_eur",
    "log_market_value"
]

candidate_features = [
    "age_fbref",
    "minutes",
    "goals",
    "assists",
    "shots",
    "shots_on_target",
    "goals_per90",
    "assists_per90",
    "shots_per90",
    "interceptions",
    "tackles_won",
    "fouls_committed",
    "fouls_drawn",
    "crosses",
    "offsides",
    "team_goals",
    "goal_difference",
    "points_per_match"
]

feature_audit = final_model_data[candidate_features].isna().sum()

feature_audit[feature_audit > 0]
# Out:
# Series([], dtype: int64)

# %%
non_feature_columns = [
    "league",
    "season",
    "club",
    "player_name",
    "nation",
    "position_fbref",
    "position_tm",
    "position_group",
    "market_value_eur",
    "log_market_value"
]


potential_features = [
    col for col in final_model_data.columns
    if col not in non_feature_columns
]

#potential_features = potential_features.drop(columns=['age_tm'], axis=1, inplace=True)

potential_features
# Out:
# ['age_fbref',
#  'born',
#  'matches_played',
#  'starts',
#  'minutes',
#  'nineties',
#  'goals',
#  'assists',
#  'goal_contributions',
#  'non_penalty_goals',
#  'penalty_goals',
#  'penalty_attempts',
#  'yellow_cards',
#  'red_cards',
#  'goals_per90',
#  'assists_per90',
#  'ga_per90',
#  'npg_per90',
#  'npga_per90',
#  'shots',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'shots_per90',
#  'shots_on_target_per90',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'minutes_per_match',
#  'minutes_pct',
#  'starts_per_match',
#  'complete_matches',
#  'substitute_appearances',
#  'minutes_per_sub',
#  'unused_substitute',
#  'points_per_match',
#  'team_goals',
#  'team_goals_against',
#  'goal_difference',
#  'goal_difference_per90',
#  'on_off',
#  'second_yellows',
#  'fouls_committed',
#  'fouls_drawn',
#  'offsides',
#  'crosses',
#  'interceptions',
#  'tackles_won',
#  'own_goals',
#  'goals_against',
#  'goals_against_per90',
#  'shots_on_target_against',
# ...

# %%
potential_features.remove("age_tm")

"age_tm" in potential_features
# Out:
# False

# %%
excluded_columns = [
    # Identifiers and metadata
    "league",
    "season",
    "club",
    "player_name",
    "nation",
    "position_fbref",
    "position_tm",

    # Target variables
    "market_value_eur",
    "log_market_value",

    # Position variable
    "position_group",

    # Features excluded after missing-value analysis
    "shots_on_target_pct",
    "goals_per_shot",
    "goals_per_shot_on_target",
    "starts_per_match",
    "minutes_per_sub",
    "on_off",

    # Duplicate age variable
    "age_tm"
]

potential_features = [
    col for col in final_model_data.columns
    if col not in excluded_columns
]

potential_features
# Out:
# ['age_fbref',
#  'born',
#  'matches_played',
#  'starts',
#  'minutes',
#  'nineties',
#  'goals',
#  'assists',
#  'goal_contributions',
#  'non_penalty_goals',
#  'penalty_goals',
#  'penalty_attempts',
#  'yellow_cards',
#  'red_cards',
#  'goals_per90',
#  'assists_per90',
#  'ga_per90',
#  'npg_per90',
#  'npga_per90',
#  'shots',
#  'shots_on_target',
#  'shots_per90',
#  'shots_on_target_per90',
#  'minutes_per_match',
#  'minutes_pct',
#  'complete_matches',
#  'substitute_appearances',
#  'unused_substitute',
#  'points_per_match',
#  'team_goals',
#  'team_goals_against',
#  'goal_difference',
#  'goal_difference_per90',
#  'second_yellows',
#  'fouls_committed',
#  'fouls_drawn',
#  'offsides',
#  'crosses',
#  'interceptions',
#  'tackles_won',
#  'own_goals',
#  'goals_against',
#  'goals_against_per90',
#  'shots_on_target_against',
#  'saves',
#  'save_percentage',
#  'wins',
#  'draws',
#  'losses',
#  'clean_sheets',
#  'clean_sheet_percentage',
# ...

# %%
print(len(potential_features))
# Out:
# 56

# %%
potential_features_missing = (
    final_model_data[potential_features]
    .isna()
    .sum()
    .sort_values(ascending=False)
)

potential_features_missing[potential_features_missing > 0]
# Out:
# penalty_save_percentage    2012
# clean_sheet_percentage     1967
# save_percentage            1963
# draws                      1962
# goals_against              1962
# shots_on_target_against    1962
# saves                      1962
# wins                       1962
# goals_against_per90        1962
# losses                     1962
# penalties_faced            1962
# penalties_saved            1962
# penalties_missed           1962
# penalties_conceded         1962
# clean_sheets               1962
# dtype: int64

# %%
goalkeeper_specific_features = [
    "goals_against",
    "goals_against_per90",
    "shots_on_target_against",
    "saves",
    "save_percentage",
    "wins",
    "draws",
    "losses",
    "clean_sheets",
    "clean_sheet_percentage",
    "penalties_faced",
    "penalties_saved",
    "penalties_missed",
    "penalties_conceded",
    "penalty_save_percentage"
]

# Separate columns available for only goalkeepers from features available to outfield players
common_features = [
    feature
    for feature in potential_features
    if feature not in goalkeeper_specific_features
]

common_features
# Out:
# ['age_fbref',
#  'born',
#  'matches_played',
#  'starts',
#  'minutes',
#  'nineties',
#  'goals',
#  'assists',
#  'goal_contributions',
#  'non_penalty_goals',
#  'penalty_goals',
#  'penalty_attempts',
#  'yellow_cards',
#  'red_cards',
#  'goals_per90',
#  'assists_per90',
#  'ga_per90',
#  'npg_per90',
#  'npga_per90',
#  'shots',
#  'shots_on_target',
#  'shots_per90',
#  'shots_on_target_per90',
#  'minutes_per_match',
#  'minutes_pct',
#  'complete_matches',
#  'substitute_appearances',
#  'unused_substitute',
#  'points_per_match',
#  'team_goals',
#  'team_goals_against',
#  'goal_difference',
#  'goal_difference_per90',
#  'second_yellows',
#  'fouls_committed',
#  'fouls_drawn',
#  'offsides',
#  'crosses',
#  'interceptions',
#  'tackles_won',
#  'own_goals']

# %%
print("Number of potential features:", len(potential_features))
print("Number of common features:", len(common_features))
# Out:
# Number of potential features: 56
# Number of common features: 41

# %%
goalkeeper_specific_features = [
    feature
    for feature in potential_features
    if feature not in common_features
]

goalkeeper_specific_features
# Out:
# ['goals_against',
#  'goals_against_per90',
#  'shots_on_target_against',
#  'saves',
#  'save_percentage',
#  'wins',
#  'draws',
#  'losses',
#  'clean_sheets',
#  'clean_sheet_percentage',
#  'penalties_faced',
#  'penalties_saved',
#  'penalties_missed',
#  'penalties_conceded',
#  'penalty_save_percentage']

# %%
for feature in common_features:
    print(feature)
# Out:
# age_fbref
# born
# matches_played
# starts
# minutes
# nineties
# goals
# assists
# goal_contributions
# non_penalty_goals
# penalty_goals
# penalty_attempts
# yellow_cards
# red_cards
# goals_per90
# assists_per90
# ga_per90
# npg_per90
# npga_per90
# shots
# shots_on_target
# shots_per90
# shots_on_target_per90
# minutes_per_match
# minutes_pct
# complete_matches
# substitute_appearances
# unused_substitute
# points_per_match
# team_goals
# team_goals_against
# goal_difference
# goal_difference_per90
# second_yellows
# fouls_committed
# fouls_drawn
# offsides
# crosses
# interceptions
# tackles_won
# own_goals

# %%
common_model_features = [
    "age_fbref",
    "matches_played",
    "starts",
    "minutes",
    "goals",
    "assists",
    "goals_per90",
    "assists_per90",
    "shots",
    "shots_on_target",
    "shots_per90",
    "shots_on_target_per90",
    "yellow_cards",
    "red_cards",
    "points_per_match",
    "team_goals",
    "team_goals_against",
    "goal_difference",
    "fouls_committed",
    "fouls_drawn",
    "offsides",
    "crosses",
    "interceptions",
    "tackles_won",
    "own_goals"
]

final_model_data[common_model_features].isna().sum().sort_values(ascending=False)
# Out:
# age_fbref                0
# red_cards                0
# tackles_won              0
# interceptions            0
# crosses                  0
# offsides                 0
# fouls_drawn              0
# fouls_committed          0
# goal_difference          0
# team_goals_against       0
# team_goals               0
# points_per_match         0
# yellow_cards             0
# matches_played           0
# shots_on_target_per90    0
# shots_per90              0
# shots_on_target          0
# shots                    0
# assists_per90            0
# goals_per90              0
# assists                  0
# goals                    0
# minutes                  0
# starts                   0
# own_goals                0
# dtype: int64

# %% [markdown]
# ## Model Development Pipeline Begins

# %%
# Split data into features and target variable

X_global = final_model_data[common_model_features]
y = final_model_data["log_market_value"]

# %%
attacker_data = final_model_data[
    final_model_data["position_group"] == "Attacker"
]

midfielder_data = final_model_data[
    final_model_data["position_group"] == "Midfielder"
]

defender_data = final_model_data[
    final_model_data["position_group"] == "Defender"
]

goalkeeper_data = final_model_data[
    final_model_data["position_group"] == "Goalkeeper"
]

# %% [markdown]
# ## Train-Test Split and Cross-Validation:
#
# - The final modelling dataset was divided into training and testing sets using an 80:20 split. The training set was used for model development, including model fitting, hyperparameter tuning and cross-validation. The testing subset was held out during model development and was used only for the final evaluation of the trained models on unseen observations.
#
# - A fixed random state of 181 was used to ensure that the data split was reproducible. This value corresponds to the final three digits of the researcher's student identification number.
#
# - The global dataset contained 2,116 player-season observations. Consequently, 1,692 observations were allocated to the training set, and 424 observations were reserved for the testing set.
#
# - Within the training set, k-fold cross-validation was used during model development. The test subset was not used during cross-validation or model selection in order to provide an independent evaluation of model performance.
#
# ## Limitations:
# - Given that the dataset is a panel-like collection of player-season observations, the random split means the same player could potentially appear in both training and test sets in different seasons.

# %% [markdown]
# ### Train-Test Splits For Both Global and Position-specific models Data

# %%
# The last 3 digits of my Student ID (R00277181).

random_for_all = 181

# %%
# Train-test split for global model

X_global = final_model_data[common_model_features]
y_global = final_model_data["log_market_value"]

X_global_train, X_global_test, y_global_train, y_global_test = train_test_split(
    X_global,
    y_global,
    test_size=0.20,
    random_state=random_for_all
)

print("Training observations:", len(X_global_train))
print("Testing observations:", len(X_global_test))
# Out:
# Training observations: 1692
# Testing observations: 424

# %%
# Train-test split for attackers

attackers = final_model_data[
    final_model_data["position_group"] == "Attacker"
]

X_attackers = attackers[common_model_features]
y_attackers = attackers["log_market_value"]

X_attackers_train, X_attackers_test, y_attackers_train, y_attackers_test = train_test_split(
    X_attackers,
    y_attackers,
    test_size=0.20,
    random_state=random_for_all
)

print("Training observations:", len(X_attackers_train))
print("Testing observations:", len(X_attackers_test))
# Out:
# Training observations: 475
# Testing observations: 119

# %%
# Train-test split for midfielders

midfielders = final_model_data[
    final_model_data["position_group"] == "Midfielder"
]

X_midfielders = midfielders[common_model_features]
y_midfielders = midfielders["log_market_value"]

X_midfielders_train, X_midfielders_test, y_midfielders_train, y_midfielders_test = train_test_split(
    X_midfielders,
    y_midfielders,
    test_size=0.20,
    random_state=random_for_all
)

print("Training observations:", len(X_midfielders_train))
print("Testing observations:", len(X_midfielders_test))
print()
print()
print(len(X_midfielders))
print(len(y_midfielders))
# Out:
# Training observations: 516
# Testing observations: 129
#
#
# 645
# 645

# %%
# Train-test split for defenders

defenders = final_model_data[
    final_model_data["position_group"] == "Defender"
]

X_defenders = defenders[common_model_features]
y_defenders = defenders["log_market_value"]

X_defenders_train, X_defenders_test, y_defenders_train, y_defenders_test = train_test_split(
    X_defenders,
    y_defenders,
    test_size=0.20,
    random_state=random_for_all
)

print("Training observations:", len(X_defenders_train))
print("Testing observations:", len(X_defenders_test))
# Out:
# Training observations: 578
# Testing observations: 145

# %%
# Train-test split for goalkeepers

goalkeepers = final_model_data[
    final_model_data["position_group"] == "Goalkeeper"
]

X_goalkeepers = goalkeepers[common_model_features]
y_goalkeepers = goalkeepers["log_market_value"]

X_goalkeepers_train, X_goalkeepers_test, y_goalkeepers_train, y_goalkeepers_test = train_test_split(
    X_goalkeepers,
    y_goalkeepers,
    test_size=0.20,
    random_state=random_for_all
)

print("Training observations:", len(X_goalkeepers_train))
print("Testing observations:", len(X_goalkeepers_test))
# Out:
# Training observations: 123
# Testing observations: 31

# %%
print("Attackers:", len(attackers))
print("Midfielders:", len(midfielders))
print("Defenders:", len(defenders))
print("Goalkeepers:", len(goalkeepers))
# Out:
# Attackers: 594
# Midfielders: 645
# Defenders: 723
# Goalkeepers: 154

# %% [markdown]
# # Linear Regression Development & Evaluation

# %%
# Global Model
global_lr = run_linear_regression(X_global_train, 
                              X_global_test, 
                              y_global_train, 
                              y_global_test, 
                              "Global")

# Attackers Linear Regression
attacker_lr = run_linear_regression(X_attackers_train, 
                                X_attackers_test, 
                                y_attackers_train, 
                                y_attackers_test, 
                                "Attackers")

# Midfielders Linear Regression
midfielder_lr = run_linear_regression(X_midfielders_train, 
                                  X_midfielders_test, 
                                  y_midfielders_train, 
                                  y_midfielders_test, 
                                  "Midfielders")

# Defenders Linear Regression
defender_lr = run_linear_regression(X_defenders_train, 
                                  X_defenders_test, 
                                  y_defenders_train, 
                                  y_defenders_test, 
                                  "Defenders")

# Goalkeepers Linear Regression
goalkeeper_lr = run_linear_regression(X_goalkeepers_train, 
                                  X_goalkeepers_test, 
                                  y_goalkeepers_train, 
                                  y_goalkeepers_test, 
                                  "Goalkeepers")


results = [
    global_lr,
    attacker_lr,
    midfielder_lr,
    defender_lr,
    goalkeeper_lr
]

lr_results = pd.DataFrame(results)
lr_results
# Out:
# Global Linear Regression completed.
# Attackers Linear Regression completed.
# Midfielders Linear Regression completed.
# Defenders Linear Regression completed.
# Goalkeepers Linear Regression completed.
#            Algorithm      Dataset       MAE      RMSE        R2
# 0  Linear Regression       Global  0.695954  0.964814  0.493108
# 1  Linear Regression    Attackers  0.665928  0.907254  0.493158
# 2  Linear Regression  Midfielders  0.787083  1.062304  0.436782
# 3  Linear Regression    Defenders  0.737626  1.378648 -0.512972
# 4  Linear Regression  Goalkeepers  0.653722  0.800336  0.685429

# %% [markdown]
# # XGBoost Model Development & Evaluation

# %%
# Global XGBoost Model
global_xgb = run_xgboost(X_global_train, 
                              X_global_test, 
                              y_global_train, 
                              y_global_test, 
                              "Global")

# Attackers XGBoost
attacker_xgb = run_xgboost(X_attackers_train, 
                                X_attackers_test, 
                                y_attackers_train, 
                                y_attackers_test, 
                                "Attackers")

# Midfielders XGBoost
midfielder_xgb = run_xgboost(X_midfielders_train, 
                                  X_midfielders_test, 
                                  y_midfielders_train, 
                                  y_midfielders_test, 
                                  "Midfielders")

# Defenders XGBoost
defender_xgb = run_xgboost(X_defenders_train, 
                                  X_defenders_test, 
                                  y_defenders_train, 
                                  y_defenders_test, 
                                  "Defenders")

# Goalkeepers XGBoost
goalkeeper_xgb = run_xgboost(X_goalkeepers_train, 
                                  X_goalkeepers_test, 
                                  y_goalkeepers_train, 
                                  y_goalkeepers_test, 
                                  "Goalkeepers")


results = [
    global_xgb,
    attacker_xgb,
    midfielder_xgb,
    defender_xgb,
    goalkeeper_xgb
]

xgb_results = pd.DataFrame(results)
xgb_results
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Global XGBoost completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Attackers XGBoost completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Midfielders XGBoost completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Defenders XGBoost completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Goalkeepers XGBoost completed.
#   Algorithm      Dataset       MAE      RMSE        R2  \
# 0   XGBoost       Global  0.538886  0.755635  0.689077
# 1   XGBoost    Attackers  0.565651  0.745578  0.657705
# 2   XGBoost  Midfielders  0.580629  0.798015  0.682165
# 3   XGBoost    Defenders  0.533951  0.761764  0.538081
# 4   XGBoost  Goalkeepers  0.688303  0.872641  0.626023
#
#                                      Best Parameters  \
# 0  {'model__learning_rate': 0.05, 'model__max_dep...
# 1  {'model__learning_rate': 0.05, 'model__max_dep...
# ...

# %% [markdown]
# # LightGBM Development & Evaluation

# %%
# Global LightGBM
global_lgbm = run_light_gbm(X_global_train, 
                              X_global_test, 
                              y_global_train, 
                              y_global_test, 
                              "Global")

# Attackers LightGBM
attacker_lgbm = run_light_gbm(X_attackers_train, 
                                X_attackers_test, 
                                y_attackers_train, 
                                y_attackers_test, 
                                "Attackers")

# Midfielders LightGBM
midfielder_lgbm = run_light_gbm(X_midfielders_train, 
                                  X_midfielders_test, 
                                  y_midfielders_train, 
                                  y_midfielders_test, 
                                  "Midfielders")

# Defenders LightGBM
defender_lgbm = run_light_gbm(X_defenders_train, 
                                  X_defenders_test, 
                                  y_defenders_train, 
                                  y_defenders_test, 
                                  "Defenders")

# Goalkeepers LightGBM
goalkeeper_lgbm = run_light_gbm(X_goalkeepers_train, 
                                  X_goalkeepers_test, 
                                  y_goalkeepers_train, 
                                  y_goalkeepers_test, 
                                  "Goalkeepers")


results = [
    global_lgbm,
    attacker_lgbm,
    midfielder_lgbm,
    defender_lgbm,
    goalkeeper_lgbm
]

lgbm_results = pd.DataFrame(results)
lgbm_results
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Global LightGBM completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Attackers LightGBM completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Midfielders LightGBM completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Defenders LightGBM completed.
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Goalkeepers LightGBM completed.
#   Algorithm      Dataset       MAE      RMSE        R2  \
# 0  LightGBM       Global  0.532188  0.742464  0.699822
# 1  LightGBM    Attackers  0.602626  0.799836  0.606073
# 2  LightGBM  Midfielders  0.597233  0.784348  0.692959
# 3  LightGBM    Defenders  0.546197  0.772805  0.524594
# 4  LightGBM  Goalkeepers  0.640808  0.840031  0.653451
#
#                                      Best Parameters  \
# 0  {'model__learning_rate': 0.01, 'model__n_estim...
# 1  {'model__learning_rate': 0.01, 'model__n_estim...
# ...

# %% [markdown]
# # Random Forest Model Development and Evaluation

# %%
# Global Random Forest Model
global_rf = run_random_forest(X_global_train, 
                              X_global_test, 
                              y_global_train, 
                              y_global_test, 
                              "Global")

# Attackers Random Forest Model
attacker_rf = run_random_forest(X_attackers_train, 
                                X_attackers_test, 
                                y_attackers_train, 
                                y_attackers_test, 
                                "Attackers")

# Midfielders Random Forest Model
midfielder_rf = run_random_forest(X_midfielders_train, 
                                  X_midfielders_test, 
                                  y_midfielders_train, 
                                  y_midfielders_test, 
                                  "Midfielders")

# Defenders Random Forest Model
defender_rf = run_random_forest(X_defenders_train, 
                                  X_defenders_test, 
                                  y_defenders_train, 
                                  y_defenders_test, 
                                  "Defenders")

# Goalkeepers Random Forest Model
goalkeeper_rf = run_random_forest(X_goalkeepers_train, 
                                  X_goalkeepers_test, 
                                  y_goalkeepers_train, 
                                  y_goalkeepers_test, 
                                  "Goalkeepers")


results = [
    global_rf,
    attacker_rf,
    midfielder_rf,
    defender_rf,
    goalkeeper_rf
]

rf_results = pd.DataFrame(results)
rf_results
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Global Random Forest completed.
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Attackers Random Forest completed.
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Midfielders Random Forest completed.
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Defenders Random Forest completed.
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Goalkeepers Random Forest completed.
#        Algorithm      Dataset       MAE      RMSE        R2  \
# 0  Random Forest       Global  0.534003  0.749176  0.694370
# 1  Random Forest    Attackers  0.569390  0.735735  0.666683
# 2  Random Forest  Midfielders  0.608511  0.805720  0.675998
# 3  Random Forest    Defenders  0.541974  0.764032  0.535327
# 4  Random Forest  Goalkeepers  0.719417  0.911433  0.592035
#
#                                      Best Parameters  \
# 0  {'model__max_depth': None, 'model__min_samples...
# ...

# %% [markdown]
# # Final Model Results

# %%
print(type(lr_results))
print(type(rf_results))
print(type(xgb_results))
print(type(lgbm_results))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
general_results = pd.concat(
    [
        lr_results,
        rf_results,
        lgbm_results,
        xgb_results
    ],
    ignore_index=True
)

general_results
# Out:
#             Algorithm      Dataset       MAE      RMSE        R2  \
# 0   Linear Regression       Global  0.695954  0.964814  0.493108
# 1   Linear Regression    Attackers  0.665928  0.907254  0.493158
# 2   Linear Regression  Midfielders  0.787083  1.062304  0.436782
# 3   Linear Regression    Defenders  0.737626  1.378648 -0.512972
# 4   Linear Regression  Goalkeepers  0.653722  0.800336  0.685429
# 5       Random Forest       Global  0.534003  0.749176  0.694370
# 6       Random Forest    Attackers  0.569390  0.735735  0.666683
# 7       Random Forest  Midfielders  0.608511  0.805720  0.675998
# 8       Random Forest    Defenders  0.541974  0.764032  0.535327
# 9       Random Forest  Goalkeepers  0.719417  0.911433  0.592035
# 10           LightGBM       Global  0.532188  0.742464  0.699822
# 11           LightGBM    Attackers  0.602626  0.799836  0.606073
# 12           LightGBM  Midfielders  0.597233  0.784348  0.692959
# ...

# %%
results_table = general_results.drop(
    columns=["Best Parameters", "Best Estimator"]
).copy()

results_table["MAE"] = results_table["MAE"].round(3)
results_table["RMSE"] = results_table["RMSE"].round(3)
results_table["R2"] = results_table["R2"].round(3)

results_table

general_results.to_csv(
    "/Users/kachi/Documents/Thesis/data/processed/general_model_results.csv",
    index=False
)

# %%
final_model_data.to_csv(
    "../data/final_model_data.csv",
    index=False
)

# %% [markdown]
# # Global comparison (R²)

# %%
global_results = results_table[
    results_table["Dataset"] == "Global"
]

plt.figure(figsize=(8,5), dpi=300)

bars = plt.bar(
    global_results["Algorithm"],
    global_results["R2"]
)

plt.title("Global Model Comparison (R²)")
plt.xlabel("Algorithm")
plt.ylabel("R²")

for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height()+0.005,
        f"{bar.get_height():.3f}",
        ha="center",
        va="bottom"
    )

plt.savefig(
    "/Users/kachi/Documents/Thesis/figures/global_r2_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Global comparison (MAE)

# %%
plt.figure(figsize=(8,5), dpi=300)

bars = plt.bar(
    global_results["Algorithm"],
    global_results["MAE"]
)

plt.title("Global Model Comparison (MAE)")
plt.xlabel("Algorithm")
plt.ylabel("MAE")

for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height()+0.005,
        f"{bar.get_height():.3f}",
        ha="center",
        va="bottom"
    )
plt.savefig(
    "/Users/kachi/Documents/Thesis/figures/global_mae_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Global comparison (RMSE)

# %%
plt.figure(figsize=(8,5), dpi=300)

bars = plt.bar(
    global_results["Algorithm"],
    global_results["RMSE"]
)

plt.title("Global Model Comparison (RMSE)")
plt.xlabel("Algorithm")
plt.ylabel("RMSE")

for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height()+0.005,
        f"{bar.get_height():.3f}",
        ha="center",
        va="bottom"
    )
    
plt.savefig(
    "/Users/kachi/Documents/Thesis/figures/global_rmse_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Position-specific comparison (R²)

# %%
pivot_r2 = results_table.pivot(
    index="Dataset",
    columns="Algorithm",
    values="R2"
)

pivot_r2.plot(
    kind="bar",
    figsize=(10,6)
)

plt.title("Position-Specific Model Comparison (R²)")
plt.xlabel("Dataset")
plt.ylabel("R²")

plt.xticks(rotation=0)

plt.savefig(
    "/Users/kachi/Documents/Thesis/figures/position_specific_r2_model.png",
    dpi=300,
    bbox_inches="tight"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Position-Specific Model Plots

# %%
position_results = general_results[
    general_results["Dataset"] != "Global"
].copy()

position_results
# Out:
#             Algorithm      Dataset       MAE      RMSE        R2  \
# 1   Linear Regression    Attackers  0.665928  0.907254  0.493158
# 2   Linear Regression  Midfielders  0.787083  1.062304  0.436782
# 3   Linear Regression    Defenders  0.737626  1.378648 -0.512972
# 4   Linear Regression  Goalkeepers  0.653722  0.800336  0.685429
# 6       Random Forest    Attackers  0.569390  0.735735  0.666683
# 7       Random Forest  Midfielders  0.608511  0.805720  0.675998
# 8       Random Forest    Defenders  0.541974  0.764032  0.535327
# 9       Random Forest  Goalkeepers  0.719417  0.911433  0.592035
# 11           LightGBM    Attackers  0.602626  0.799836  0.606073
# 12           LightGBM  Midfielders  0.597233  0.784348  0.692959
# 13           LightGBM    Defenders  0.546197  0.772805  0.524594
# 14           LightGBM  Goalkeepers  0.640808  0.840031  0.653451
# 16            XGBoost    Attackers  0.565651  0.745578  0.657705
# ...

# %% [markdown]
# # Position-Specific Model Comparison (MAE)

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=position_results,
    x="Dataset",
    y="MAE",
    hue="Algorithm"
)

plt.title("Position-Specific Model Comparison (MAE)")
plt.xlabel("Playing Position")
plt.ylabel("Mean Absolute Error (MAE)")

plt.legend(title="Algorithm")

plt.tight_layout()

plt.savefig(
    "../figures/position_specific_mae.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Position-Specific Model Comparison (RMSE)

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=position_results,
    x="Dataset",
    y="RMSE",
    hue="Algorithm"
)

plt.title("Position-Specific Model Comparison (RMSE)")
plt.xlabel("Playing Position")
plt.ylabel("Root Mean Square Error (RMSE)")

plt.legend(title="Algorithm")

plt.tight_layout()

plt.savefig(
    "../figures/position_specific_rmse.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Position-Specific Model Comparison ($R^2$)

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=position_results,
    x="Dataset",
    y="R2",
    hue="Algorithm"
)

plt.title("Position-Specific Model Comparison ($R^2$)")
plt.xlabel("Playing Position")
plt.ylabel("$R^2$")

plt.legend(title="Algorithm")

plt.tight_layout()

plt.savefig(
    "../figures/position_specific_r2.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Actual vs Predicted Values (Global LightGBM)

# %%
best_lgbm = lgbm_results.loc[
    lgbm_results["Dataset"] == "Global",
    "Best Estimator"
].iloc[0]

y_pred_global_lgbm = best_lgbm.predict(
    X_global_test
)


plt.figure(figsize=(7,7))

plt.scatter(
    y_global_test,
    y_pred_global_lgbm,
    alpha=0.6,
    edgecolors="black"
)

plt.plot(
    [y_global_test.min(), y_global_test.max()],
    [y_global_test.min(), y_global_test.max()],
    color="red",
    linestyle="--",
    linewidth=2,
    label="Perfect Prediction"
)

plt.xlabel("Actual Log Market Value")
plt.ylabel("Predicted Log Market Value")
plt.title("Actual vs Predicted Values (Global LightGBM)")

plt.legend()

plt.tight_layout()

plt.savefig(
    "../figures/global_lgbm_actual_vs_predicted.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Residual Plot

# %%
residuals = y_global_test - y_pred_global_lgbm

plt.figure(figsize=(8,6))

plt.scatter(
    y_pred_global_lgbm,
    residuals,
    alpha=0.6,
    edgecolors="black"
)

plt.axhline(
    y=0,
    color="red",
    linestyle="--"
)

plt.xlabel("Predicted Log Market Value")
plt.ylabel("Residuals")
plt.title("Residual Plot (Global LightGBM)")

plt.tight_layout()

plt.savefig(
    "../figures/global_lgbm_residuals.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Top 20 Feature Importances (Global LightGBM)

# %%
# Retrieve best global LightGBM pipeline
best_lgbm = lgbm_results.loc[
    lgbm_results["Dataset"] == "Global",
    "Best Estimator"
].iloc[0]

# Extract the fitted LightGBM model
lgbm_model = best_lgbm.named_steps["model"]

# Create feature importance dataframe
feature_importance = pd.DataFrame({
    "Feature": common_model_features,
    "Importance": lgbm_model.feature_importances_
})

# Sort by importance
feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

# Keep Top 20 features
top20 = feature_importance.head(20)

# Plot
plt.figure(figsize=(10,8))

sns.barplot(
    data=top20,
    x="Importance",
    y="Feature"
)

plt.title("Top 20 Feature Importances (Global LightGBM)")
plt.xlabel("Feature Importance")
plt.ylabel("Feature")

plt.tight_layout()

plt.savefig(
    "../figures/global_lgbm_feature_importance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Position-specific Modelling winners

# %%
# MAE

position_results.loc[
    position_results.groupby("Dataset")["MAE"].idxmin(),
    ["Dataset", "Algorithm", "MAE"]
].sort_values("Dataset")
# Out:
#         Dataset Algorithm       MAE
# 16    Attackers   XGBoost  0.565651
# 18    Defenders   XGBoost  0.533951
# 14  Goalkeepers  LightGBM  0.640808
# 17  Midfielders   XGBoost  0.580629

# %%
# RMSE

position_results.loc[
    position_results.groupby("Dataset")["RMSE"].idxmin(),
    ["Dataset", "Algorithm", "RMSE"]
].sort_values("Dataset")
# Out:
#         Dataset          Algorithm      RMSE
# 6     Attackers      Random Forest  0.735735
# 18    Defenders            XGBoost  0.761764
# 4   Goalkeepers  Linear Regression  0.800336
# 12  Midfielders           LightGBM  0.784348

# %%
# R²

position_results.loc[
    position_results.groupby("Dataset")["R2"].idxmax(),
    ["Dataset", "Algorithm", "R2"]
].sort_values("Dataset")
# Out:
#         Dataset          Algorithm        R2
# 6     Attackers      Random Forest  0.666683
# 18    Defenders            XGBoost  0.538081
# 4   Goalkeepers  Linear Regression  0.685429
# 12  Midfielders           LightGBM  0.692959
